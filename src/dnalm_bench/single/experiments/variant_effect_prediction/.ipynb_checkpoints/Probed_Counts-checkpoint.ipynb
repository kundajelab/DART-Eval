# %%
import pandas as pd
import glob
import os
from sklearn.metrics import average_precision_score, precision_recall_curve, auc
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr, spearmanr
from scipy.stats import mannwhitneyu

# %%
from variant_tasks import *

# %% [markdown]
# ## Nucleotide Transformer

# %%
model_name="nucleotide-transformer-v2-500m-multi-species"
model="Nucleotide Transformer"

# %%
ctrl_counts, sig_counts, filtered_var_eu_caQTLs_df = sig_ctrl_variants_Eu_CaQTLs_probed_counts(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Eu.CaQTLS.counts.tsv")
nt_eur_stat, nt_eur_pval = mannwhitneyu(ctrl_counts, sig_counts, alternative="less")
nt_eur_stat, nt_eur_pval
# Out:
# (156730, 29)
# 111915 9851
# (562168117.5, 0.9994586041587323)

# %%
ctrl_counts, sig_counts, filtered_var_eu_caQTLs_df = sig_ctrl_variants_Eu_CaQTLs_probed_counts(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Eu.CaQTLsae.2000.counts.tsv")
nt_eur_stat, nt_eur_pval = mannwhitneyu(ctrl_counts, sig_counts, alternative="less")
nt_eur_stat, nt_eur_pval

# %%
data = [ctrl_counts, sig_counts]

# Create the boxplot
plt.boxplot(data)

# Customizing the plot
plt.xticks([1, 2], ['Control', 'Significant']) 
plt.ylabel('Value') 
plt.title(f'Control vs. Significant for {model} Eu CaQTLs')  
plt.show()

# %%
threshold = 3
filtered_var_eucaqtls_df_sig = filtered_var_eu_caQTLs_df[filtered_var_eu_caQTLs_df["Log10_BF"]>threshold].copy(deep=True)
beta_logfc(filtered_var_eucaqtls_df_sig, f"{model} European Significant caQTLs")

# %%
ctrl_afr, sig_afr, filtered_var_afr_caQTLs_df = sig_ctrl_variants_Afr_CaQTLs_probed_counts(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Afr.CaQTLS.counts.tsv")
nt_afr_stat, nt_afr_pval = mannwhitneyu(ctrl_afr, sig_afr, alternative="less")
nt_afr_stat, nt_afr_pval
# Out:
# unique label values [False  True]
# 101283 8363
# (416711262.0, 0.007230974168134685)

# %%
data = [ctrl_afr, sig_afr]

# Create the boxplot
plt.boxplot(data)

# Customizing the plot
plt.xticks([1, 2], ['Control', 'Significant']) 
plt.ylabel('Value') 
plt.title(f'Control vs. Significant for {model} Afr CaQTLs')  
plt.show()

# %%
filtered_var_afrcaqtls_df_sig = filtered_var_afr_caQTLs_df[filtered_var_afr_caQTLs_df["label"]==1]

beta_logfc(filtered_var_afrcaqtls_df_sig, f"{model} African Significant caQTLs")

# %%
afr_asb = variants_Afr_ASB_CaQTLs_probed_counts(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Afr.ASB.CaQTLS.counts.tsv")
effect_size_logfc(afr_asb, f"{model} African ASB caQTLs")
# Out:
# Index(['chr_hg38', 'pos_hg38', 'allele1', 'allele2', 'IsUsed', 'rsid',
#        'snp_id', 'meanLog2FC', 'GM12878.ENCSR637XSC.mean.logfc',
#        'GM12878.ENCSR637XSC.mean.sign.jsd', 'GM12878.ENCSR000EMT.mean.logfc',
#        'GM12878.ENCSR000EMT.mean.sign.jsd',
#        'GM12878.ENCSR637XSC.sub.50M.mean.logfc',
#        'GM12878.ENCSR637XSC.sub.50M.mean.sign.jsd', 'allele1_counts',
#        'allele2_counts'],
#       dtype='object')

# %%
df = pd.read_csv(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/gm12878.dsqtls.benchmarking.counts.tsv", sep="\t")
df = pd.read_csv("/oak/stanford/groups/akundaje/anusri/variant-benchmakring/gm12878.dsqtls.benchmarking.tsv", sep="\t")
df[df["var.isused"]]
# Out:
#       var.chrom    var.pos var.allele1 var.allele2     var.rsid  var.label  \
# 0          chr1     856583           A           G  rs141671872          1
# 1          chr1     911595           G           A    rs7417106          1
# 2          chr1    1186502           T           A    rs6603785          1
# 3          chr1    1227412           A           G  rs112571439          1
# 4          chr1    1590575           A           G    rs9661285          1
# ...         ...        ...         ...         ...          ...        ...
# 28302      chr9  140938183           A           G    rs3750506         -1
# 28303      chr9  140953297           G           A   rs10780199         -1
# 28304      chr9  141035586           T           C    rs7852209         -1
# 28305      chr9  141061300           T           C    rs4066694         -1
# 28307      chr9  141099663           G           C   rs12340415         -1
#
#        var.isused  obs.estimate  pred.gkmsvm.encsr000emt.varscore.deltasvm  \
# 0            True        0.9301                                   2.653531
# 1            True       -0.6285                                   2.821422
# 2            True       -0.7363                                  -7.167236
# 3            True       -0.9236                                  -3.957382
# 4            True       -1.0890                                  -4.785596
# ...           ...           ...                                        ...
# 28302        True           NaN                                   0.487228
# 28303        True           NaN                                   2.804388
# 28304        True           NaN                                   0.444036
# 28305        True           NaN                                   1.363332
# 28307        True           NaN                                  -4.628759
#
#        pred.enformer.encsr000emt.varscore.sad  ...  \
# 0                                    0.000342  ...
# 1                                   -0.001241  ...
# 2                                   -0.006530  ...
# 3                                   -0.001878  ...
# 4                                   -0.008736  ...
# ...                                       ...  ...
# 28302                                0.000005  ...
# 28303                               -0.000003  ...
# 28304                                0.000001  ...
# 28305                                0.000005  ...
# 28307                                0.000054  ...
#
#        pred.chrombpnet.encsr637xsc_50m.varscore.jsd_x_aaq  \
# 0                                               0.021877
# 1                                               0.027762
# 2                                               0.029658
# 3                                               0.137196
# 4                                               0.053680
# ...                                                  ...
# 28302                                           0.000093
# 28303                                           0.000028
# 28304                                           0.000146
# 28305                                           0.000122
# 28307                                           0.001369
#
#        pred.chrombpnet.encsr637xsc_50m.varscore.logfc_x_aaq  \
# 0                                               0.127298
# 1                                               0.056287
# 2                                               0.349964
# 3                                               0.518532
# 4                                               0.103350
# ...                                                  ...
# 28302                                           0.000505
# 28303                                           0.000094
# 28304                                           0.000272
# 28305                                           0.000375
# 28307                                           0.007073
#
#        pred.chrombpnet.encsr637xsc_25m.varscore.logfc  \
# 0                                            0.291935
# 1                                            0.093192
# 2                                           -0.402188
# 3                                           -0.622704
# 4                                           -0.061906
# ...                                               ...
# 28302                                       -0.046869
# 28303                                        0.016504
# 28304                                       -0.017531
# 28305                                        0.012734
# 28307                                       -0.078796
#
#        pred.chrombpnet.encsr637xsc_25m.varscore.jsd  \
# 0                                          0.067401
# 1                                          0.036053
# 2                                         -0.038791
# 3                                         -0.222396
# 4                                         -0.050589
# ...                                             ...
# 28302                                     -0.008768
# 28303                                      0.005610
# 28304                                     -0.006130
# 28305                                      0.005202
# 28307                                     -0.024984
#
#        pred.chrombpnet.encsr637xsc_25m.varscore.crs  \
# 0                                          0.004840
# 1                                          0.002239
# 2                                          0.008839
# 3                                          0.086945
# 4                                          0.003275
# ...                                             ...
# 28302                                      0.000026
# 28303                                      0.000002
# 28304                                      0.000007
# 28305                                      0.000001
# 28307                                      0.000363
#
#        pred.chrombpnet.encsr637xsc_25m.varscore.pval  \
# 0                                           0.018692
# 1                                           0.033704
# 2                                           0.006710
# 3                                           0.000056
# 4                                           0.027075
# ...                                              ...
# 28302                                       0.540378
# 28303                                       0.876184
# 28304                                       0.744708
# 28305                                       0.890162
# 28307                                       0.167942
#
#        pred.chrombpnet.encsr637xsc_5m.varscore.logfc  \
# 0                                           0.065098
# 1                                           0.045314
# 2                                          -0.163023
# 3                                          -0.259064
# 4                                          -0.032300
# ...                                              ...
# 28302                                      -0.026908
# 28303                                       0.002748
# 28304                                      -0.005638
# 28305                                       0.004291
# 28307                                      -0.058602
#
#        pred.chrombpnet.encsr637xsc_5m.varscore.jsd  \
# 0                                         0.049902
# 1                                         0.034489
# 2                                        -0.039080
# 3                                        -0.172960
# 4                                        -0.023135
# ...                                            ...
# 28302                                    -0.006874
# 28303                                     0.003831
# 28304                                    -0.005843
# 28305                                     0.006334
# 28307                                    -0.037741
#
#        pred.chrombpnet.encsr637xsc_5m.varscore.crs  \
# 0                                         0.001360
# 1                                         0.000898
# 2                                         0.002210
# 3                                         0.027583
# 4                                         0.000802
# ...                                            ...
# 28302                                     0.000050
# 28303                                     0.000002
# 28304                                     0.000012
# 28305                                     0.000001
# 28307                                     0.000777
#
#        pred.chrombpnet.encsr637xsc_5m.varscore.pval
# 0                                          0.065265
# 1                                          0.077782
# 2                                          0.029520
# 3                                          0.000195
# 4                                          0.084252
# ...                                             ...
# 28302                                      0.525221
# 28303                                      0.930803
# 28304                                      0.783146
# 28305                                      0.939177
# 28307                                      0.092295
#
# [27373 rows x 51 columns]

# %% [markdown]
# ## DNABert2

# %%
model_name="DNABERT-2-117M"
model="DNABert2"

# %%
ctrl_counts, sig_counts, filtered_var_eu_caQTLs_df = sig_ctrl_variants_Eu_CaQTLs_probed_counts(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Eu.CaQTLS.counts.tsv")
db_eur_stat, db_eur_pval = mannwhitneyu(ctrl_counts, sig_counts, alternative="less")
db_eur_stat, db_eur_pval
# Out:
# (156730, 29)
# 111915 9851
# (529003083.0, 1.4896927886073977e-11)

# %%
data = [ctrl_counts, sig_counts]

# Create the boxplot
plt.boxplot(data)

# Customizing the plot
plt.xticks([1, 2], ['Control', 'Significant']) 
plt.ylabel('Value') 
plt.title(f'Control vs. Significant for {model} Eu CaQTLs')  
plt.show()

# %%
threshold = 3
filtered_var_eucaqtls_df_sig = filtered_var_eu_caQTLs_df[filtered_var_eu_caQTLs_df["Log10_BF"]>threshold].copy(deep=True)
beta_logfc(filtered_var_eucaqtls_df_sig, f"{model} European Significant caQTLs")

# %%
ctrl_afr, sig_afr, filtered_var_afr_caQTLs_df = sig_ctrl_variants_Afr_CaQTLs_probed_counts(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Afr.CaQTLS.counts.tsv")
db_afr_stat, db_afr_pval = mannwhitneyu(ctrl_afr, sig_afr, alternative="less")
db_afr_stat, db_afr_pval
# Out:
# unique label values [False  True]
# 101283 8363
# (427052906.5, 0.8982712157693711)

# %%
data = [ctrl_afr, sig_afr]

# Create the boxplot
plt.boxplot(data)

# Customizing the plot
plt.xticks([1, 2], ['Control', 'Significant']) 
plt.ylabel('Value') 
plt.title(f'Control vs. Significant for {model} Afr CaQTLs')  
plt.show()

# %%
filtered_var_afrcaqtls_df_sig = filtered_var_afr_caQTLs_df[filtered_var_afr_caQTLs_df["label"]==1]

beta_logfc(filtered_var_afrcaqtls_df_sig, f"{model} African Significant caQTLs")

# %%
afr_asb = variants_Afr_ASB_CaQTLs_probed_counts(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Afr.ASB.CaQTLS.counts.tsv")
effect_size_logfc(afr_asb, f"{model} African ASB caQTLs")
# Out:
# Index(['chr_hg38', 'pos_hg38', 'allele1', 'allele2', 'IsUsed', 'rsid',
#        'snp_id', 'meanLog2FC', 'GM12878.ENCSR637XSC.mean.logfc',
#        'GM12878.ENCSR637XSC.mean.sign.jsd', 'GM12878.ENCSR000EMT.mean.logfc',
#        'GM12878.ENCSR000EMT.mean.sign.jsd',
#        'GM12878.ENCSR637XSC.sub.50M.mean.logfc',
#        'GM12878.ENCSR637XSC.sub.50M.mean.sign.jsd', 'allele1_counts',
#        'allele2_counts'],
#       dtype='object')

# %% [markdown]
# ## Gena LM

# %%
model_name="gena-lm-bert-large-t2t"
model="Gena LM"

# %%
ctrl_counts, sig_counts, filtered_var_eu_caQTLs_df = sig_ctrl_variants_Eu_CaQTLs_probed_counts(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Eu.CaQTLS.counts.tsv")
glm_eur_stat, glm_eur_pval = mannwhitneyu(ctrl_counts, sig_counts, alternative="less")
glm_eur_stat, glm_eur_pval
# Out:
# (156730, 29)
# 111915 9851
# (562754942.5, 0.999712913787007)

# %%
data = [ctrl_counts, sig_counts]

# Create the boxplot
plt.boxplot(data)

# Customizing the plot
plt.xticks([1, 2], ['Control', 'Significant']) 
plt.ylabel('Value') 
plt.title(f'Control vs. Significant for {model} Eu CaQTLs')  
plt.show()

# %%
threshold = 3
filtered_var_eucaqtls_df_sig = filtered_var_eu_caQTLs_df[filtered_var_eu_caQTLs_df["Log10_BF"]>threshold].copy(deep=True)
beta_logfc(filtered_var_eucaqtls_df_sig, f"{model} European Significant caQTLs")

# %%
ctrl_afr, sig_afr, filtered_var_afr_caQTLs_df = sig_ctrl_variants_Afr_CaQTLs_probed_counts(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Afr.CaQTLS.counts.tsv")
glm_afr_stat, glm_afr_pval = mannwhitneyu(ctrl_afr, sig_afr, alternative="less")
glm_afr_stat, glm_afr_pval
# Out:
# unique label values [False  True]
# 101283 8363
# (412468637.0, 3.5844902833954825e-05)

# %%
data = [ctrl_afr, sig_afr]

# Create the boxplot
plt.boxplot(data)

# Customizing the plot
plt.xticks([1, 2], ['Control', 'Significant']) 
plt.ylabel('Value') 
plt.title(f'Control vs. Significant for {model} Afr CaQTLs')  
plt.show()

# %%
filtered_var_afrcaqtls_df_sig = filtered_var_afr_caQTLs_df[filtered_var_afr_caQTLs_df["label"]==1]

beta_logfc(filtered_var_afrcaqtls_df_sig, f"{model} African Significant caQTLs")

# %%
afr_asb = variants_Afr_ASB_CaQTLs_probed_counts(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Afr.ASB.CaQTLS.counts.tsv")
effect_size_logfc(afr_asb, f"{model} African ASB caQTLs")
# Out:
# Index(['chr_hg38', 'pos_hg38', 'allele1', 'allele2', 'IsUsed', 'rsid',
#        'snp_id', 'meanLog2FC', 'GM12878.ENCSR637XSC.mean.logfc',
#        'GM12878.ENCSR637XSC.mean.sign.jsd', 'GM12878.ENCSR000EMT.mean.logfc',
#        'GM12878.ENCSR000EMT.mean.sign.jsd',
#        'GM12878.ENCSR637XSC.sub.50M.mean.logfc',
#        'GM12878.ENCSR637XSC.sub.50M.mean.sign.jsd', 'allele1_counts',
#        'allele2_counts'],
#       dtype='object')

# %% [markdown]
# ## HyenaDNA

# %%
model_name="hyenadna-large-1m-seqlen-hf"
model="Hyena DNA"

# %%
ctrl_counts, sig_counts, filtered_var_eu_caQTLs_df = sig_ctrl_variants_Eu_CaQTLs_probed_counts(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Eu.CaQTLS.counts.tsv")
hd_eur_stat, hd_eur_pval = mannwhitneyu(ctrl_counts, sig_counts, alternative="less")
hd_eur_stat, hd_eur_pval
# Out:
# (156730, 29)
# 111915 9851
# (584052325.5, 1.0)

# %%
data = [ctrl_counts, sig_counts]

# Create the boxplot
plt.boxplot(data)

# Customizing the plot
plt.xticks([1, 2], ['Control', 'Significant']) 
plt.ylabel('Value') 
plt.title(f'Control vs. Significant for {model} Eu CaQTLs')  
plt.show()

# %%
threshold = 3
filtered_var_eucaqtls_df_sig = filtered_var_eu_caQTLs_df[filtered_var_eu_caQTLs_df["Log10_BF"]>threshold].copy(deep=True)
beta_logfc(filtered_var_eucaqtls_df_sig, f"{model} European Significant caQTLs")

# %%
ctrl_afr, sig_afr, filtered_var_afr_caQTLs_df = sig_ctrl_variants_Afr_CaQTLs_probed_counts(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Afr.CaQTLS.counts.tsv")
hd_afr_stat, hd_afr_pval = mannwhitneyu(ctrl_afr, sig_afr, alternative="less")
hd_afr_stat, hd_afr_pval
# Out:
# unique label values [False  True]
# 101283 8363
# (354339505.5, 1.2930727242581708e-139)

# %%
data = [ctrl_afr, sig_afr]

# Create the boxplot
plt.boxplot(data)

# Customizing the plot
plt.xticks([1, 2], ['Control', 'Significant']) 
plt.ylabel('Value') 
plt.title(f'Control vs. Significant for {model} Afr CaQTLs')  
plt.show()

# %%
filtered_var_afrcaqtls_df_sig = filtered_var_afr_caQTLs_df[filtered_var_afr_caQTLs_df["label"]==1]

beta_logfc(filtered_var_afrcaqtls_df_sig, f"{model} African Significant caQTLs")

# %%
afr_asb = variants_Afr_ASB_CaQTLs_probed_counts(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Afr.ASB.CaQTLS.counts.tsv")
effect_size_logfc(afr_asb, f"{model} African ASB caQTLs")
# Out:
# Index(['chr_hg38', 'pos_hg38', 'allele1', 'allele2', 'IsUsed', 'rsid',
#        'snp_id', 'meanLog2FC', 'GM12878.ENCSR637XSC.mean.logfc',
#        'GM12878.ENCSR637XSC.mean.sign.jsd', 'GM12878.ENCSR000EMT.mean.logfc',
#        'GM12878.ENCSR000EMT.mean.sign.jsd',
#        'GM12878.ENCSR637XSC.sub.50M.mean.logfc',
#        'GM12878.ENCSR637XSC.sub.50M.mean.sign.jsd', 'allele1_counts',
#        'allele2_counts'],
#       dtype='object')

# %%
from tabulate import tabulate
mydata = [
    ["HyenaDNA", hd_afr_pval, hd_eur_pval],
    ["Dnabert2", db_afr_pval, db_eur_pval],
    ["Gena LM",glm_afr_pval, glm_eur_pval],
    ["Nucleotide Transformer", nt_afr_pval, nt_eur_pval]
]
headers = ["Model", "African P value", "European P value"]
print(tabulate(mydata, headers=headers, tablefmt="grid"))
# Out:
# +------------------------+-------------------+--------------------+
# | Model                  |   African P value |   European P value |
# +========================+===================+====================+
# | HyenaDNA               |      1.29307e-139 |        1           |
# +------------------------+-------------------+--------------------+
# | Dnabert2               |      0.898271     |        1.48969e-11 |
# +------------------------+-------------------+--------------------+
# | Gena LM                |      3.58449e-05  |        0.999713    |
# +------------------------+-------------------+--------------------+
# | Nucleotide Transformer |      0.00723097   |        0.999459    |
# +------------------------+-------------------+--------------------+

# %%
bins = np.linspace(0, 0.03, 100)  # Define the bins to cover the range of both datasets

counts_ctrl, bins_ctrl = np.histogram(ctrl_counts, bins=bins)
fractions_ctrol = counts_ctrl / counts_ctrl.sum()
plt.hist(bins_ctrl[:-1], bins_ctrl, weights=fractions_ctrol, alpha=0.5, label="control")
counts_sig, bins_sig = np.histogram(sig_counts, bins=bins)
fractions_sig = counts_sig / counts_sig.sum()
plt.hist(bins_sig[:-1], bins_sig, weights=fractions_sig, alpha=0.5, label="sig")
plt.legend()

# %%
df = pd.read_csv(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Afr.CaQTLS.counts.tsv", sep="\t")

# %%
used_variants = df[df["IsUsed"]==True]
np.min(used_variants["pval"]), np.max(used_variants["pval"])
# Out:
# (2.92178e-41, 0.999995)

# %%
ctrl = used_variants[-np.log10(used_variants["pval"]) <= 3]
sig = used_variants[-np.log10(used_variants["pval"]) > 3]

# %%
if "Beta" in sig.columns:
    x = sig["Beta"]
else:
    x = sig["beta"]
y = sig["chrombpnet.encsr000emt.variantscore.logfc"]
g = sns.jointplot(x=x, y=y, 
                kind="scatter")

pearson_corr, _ = pearsonr(x, y)
spearman_corr, _ = spearmanr(x, y)

# Add the correlation coefficients to the plot
plt.subplots_adjust(top=0.9)  # Adjust the top edge of the subplot to make room for the text
plt.xlabel("Significant caQTL Betas")
# plt.ylabel()
g.figure.suptitle(f'African CaQTLs\nPearson: {pearson_corr:.4f} --- Spearman: {spearman_corr:.4f}', 
            x=0.5, y=0.98, ha='center')
plt.grid()
plt.show()

# %%
df = pd.read_csv(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Eu.CaQTLS.counts.tsv", sep="\t")
used_df = df[(df["Inside_Peak"]==True) & (df["IsUsed"]==True)].copy(deep=True)

# %%
used_df
# Out:
#           chr       Pos Ref Alt         RsID    Peak       AF  Inside_Peak  \
# 2        chr1    565286   C   T    rs1578391       7  0.59780            1
# 3        chr1    569204   T   C  rs112660509       8  0.40125            1
# 6        chr1    726944   C   G    rs3131979      14  0.74175            1
# 7        chr1    752721   A   G    rs3131972      17  0.84500            1
# 8        chr1    755940   C   T    rs3115857      18  0.59380            1
# ...       ...       ...  ..  ..          ...     ...      ...          ...
# 226341  chr22  51021271   T   C  rs540889063  277122  0.05500            1
# 226342  chr22  51059483   G   A   rs76733141  277123  0.06000            1
# 226343  chr22  51066552   C   G    rs6151406  277124  0.06000            1
# 226344  chr22  51082407   T   A   rs62241515  277125  0.42505            1
# 226345  chr22  51222052   G   A    rs2879915  277128  0.26020            1
#
#           P_Lead      Beta  ...  \
# 2       0.998561  0.886884  ...
# 3       0.477613  0.251458  ...
# 6       0.953905 -0.079065  ...
# 7       0.890193 -0.011374  ...
# 8       0.302008 -0.077224  ...
# ...          ...       ...  ...
# 226341  0.362698  0.010717  ...
# 226342  0.553273 -0.061982  ...
# 226343  0.921861  0.087364  ...
# 226344  0.315251 -0.016347  ...
# 226345  0.726414 -0.027808  ...
#
#         ENCSR637XSC.sub.50M.abs_logfc_x_jsd_x_max_percentile.mean.pval  \
# 2                                                0.379356
# 3                                                0.191231
# 6                                                0.802258
# 7                                                0.003650
# 8                                                0.674640
# ...                                                   ...
# 226341                                           0.108499
# 226342                                           0.102590
# 226343                                           0.036352
# 226344                                           0.593201
# 226345                                           0.167751
#
#         ENCSR000EMT.logfc.mean  ENCSR000EMT.jsd_sign.mean  \
# 2                    -0.018964                  -0.015143
# 3                     0.031934                   0.020760
# 6                     0.008318                   0.007418
# 7                     0.271053                   0.045088
# 8                    -0.022797                  -0.011753
# ...                        ...                        ...
# 226341               -0.025875                  -0.012848
# 226342               -0.067028                  -0.015264
# 226343               -0.084489                  -0.024247
# 226344               -0.009835                  -0.006762
# 226345               -0.003386                  -0.024856
#
#         ENCSR000EMT.abs_logfc_x_jsd_x_max_percentile.mean  \
# 2                                            2.562691e-05
# 3                                            6.229992e-04
# 6                                            1.771461e-06
# 7                                            8.781494e-03
# 8                                            5.509056e-07
# ...                                                   ...
# 226341                                       3.133266e-04
# 226342                                       1.259804e-03
# 226343                                       1.716076e-03
# 226344                                       2.876620e-06
# 226345                                       6.515610e-04
#
#         ENCSR000EMT.abs_logfc_x_jsd_x_max_percentile.mean.pval  DNASE_SAD  \
# 2                                                0.527638        0.000008
# 3                                                0.105496        0.000026
# 6                                                0.824761        0.000100
# 7                                                0.005066        0.002493
# 8                                                0.879308        0.000022
# ...                                                   ...             ...
# 226341                                           0.120968        0.000096
# 226342                                           0.054735       -0.000848
# 226343                                           0.030853       -0.000557
# 226344                                           0.707481        0.000029
# 226345                                           0.074800       -0.000366
#
#         DNASE_SAR  IsUsed  allele1_counts  allele2_counts
# 2        0.000011    True        1.108465        1.108802
# 3        0.000036    True        1.124413        1.124413
# 6        0.000133    True        1.101260        1.098455
# 7        0.003319    True        1.124413        1.124413
# 8        0.000029    True        1.124413        1.124413
# ...           ...     ...             ...             ...
# 226341   0.000099    True        1.124413        1.124413
# 226342  -0.001081    True        1.091937        1.088542
# 226343  -0.000713    True        1.124413        1.124413
# 226344   0.000038    True        1.124413        1.124413
# 226345  -0.000515    True        1.124413        1.124413
#
# [156730 rows x 29 columns]

# %%
np.min(used_df["Log10_BF"]), np.max(used_df["Log10_BF"])
# Out:
# (-2.85269667581797, 41.6367949591098)

# %%
ctrl = used_df[used_df["Log10_BF"] < -1]

# %%
sig = used_df[used_df["Log10_BF"] > 3]

# %%
if "Beta" in sig.columns:
    x = sig["Beta"]
else:
    x = sig["beta"]
y = sig["ENCSR000EMT.logfc.mean"]
g = sns.jointplot(x=x, y=y, 
                kind="scatter")

pearson_corr, _ = pearsonr(x, y)
spearman_corr, _ = spearmanr(x, y)

# Add the correlation coefficients to the plot
plt.subplots_adjust(top=0.9)  # Adjust the top edge of the subplot to make room for the text
plt.xlabel("Significant caQTL Betas")
# plt.ylabel()
g.figure.suptitle(f'European CaQTLs\nPearson: {pearson_corr:.4f} --- Spearman: {spearman_corr:.4f}', 
            x=0.5, y=0.98, ha='center')
plt.grid()
plt.show()

# %%
df = pd.read_csv(f"/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/{model_name}/GM12878/Afr.CaQTLS.counts.tsv", sep="\t")

used_variants = df[df["IsUsed"]==True]
np.min(used_variants["pval"]), np.max(used_variants["pval"])

used_variants[-np.log10(used_variants["pval"]) >= 3]

used_variants[-np.log10(used_variants["pval"]) <= 3]

ctrl = used_variants[-np.log10(used_variants["pval"]) <= 3]
sig = used_variants[-np.log10(used_variants["pval"]) > 3]

if "Beta" in sig.columns:
    x = sig["Beta"]
else:
    x = sig["beta"]
y = sig["chrombpnet.encsr000emt.variantscore.logfc"]
g = sns.jointplot(x=x, y=y, 
                kind="scatter")

pearson_corr, _ = pearsonr(x, y)
spearman_corr, _ = spearmanr(x, y)

# Add the correlation coefficients to the plot
plt.subplots_adjust(top=0.9)  # Adjust the top edge of the subplot to make room for the text
plt.xlabel("Significant caQTL Betas")
# plt.ylabel()
g.figure.suptitle(f'\nPearson: {pearson_corr:.4f} --- Spearman: {spearman_corr:.4f}', 
            x=0.5, y=0.98, ha='center')
plt.grid()
plt.show()

# %%
paths = glob.glob("/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/hyenadna-large-1m-seqlen-hf/GM12878/*")

# %%
counts_data = pd.read_csv("/oak/stanford/groups/akundaje/projects/dnalm_benchmark/variants/probing/DNABERT-2-117M/GM12878/Eu.CaQTLS.counts.tsv", sep="\t")
data = pd.read_csv("/oak/stanford/groups/akundaje/anusri/variant-benchmakring/Eu.CaQTLS.tsv", sep="\t")

# %%
data.shape[0]
# Out:
# 226346

# %%
counts_data
# Out:
#           chr       Pos Ref Alt         RsID    Peak       AF  Inside_Peak  \
# 0        chr1    875770   A   G    rs4970379       3  0.62500            2
# 1        chr1    930533   C   G    rs3128110       5  0.35435            0
# 2        chr1    565286   C   T    rs1578391       7  0.59780            1
# 3        chr1    569204   T   C  rs112660509       8  0.40125            1
# 4        chr1    748141   G   A    rs2427893      10  0.05005            0
# ...       ...       ...  ..  ..          ...     ...      ...          ...
# 226341  chr22  51021271   T   C  rs540889063  277122  0.05500            1
# 226342  chr22  51059483   G   A   rs76733141  277123  0.06000            1
# 226343  chr22  51066552   C   G    rs6151406  277124  0.06000            1
# 226344  chr22  51082407   T   A   rs62241515  277125  0.42505            1
# 226345  chr22  51222052   G   A    rs2879915  277128  0.26020            1
#
#           P_Lead      Beta  ...  \
# 0       0.044994  0.155446  ...
# 1       0.099392  0.174020  ...
# 2       0.998561  0.886884  ...
# 3       0.477613  0.251458  ...
# 4       0.988758  0.347965  ...
# ...          ...       ...  ...
# 226341  0.362698  0.010717  ...
# 226342  0.553273 -0.061982  ...
# 226343  0.921861  0.087364  ...
# 226344  0.315251 -0.016347  ...
# 226345  0.726414 -0.027808  ...
#
#         ENCSR637XSC.sub.50M.abs_logfc_x_jsd_x_max_percentile.mean.pval  \
# 0                                                0.121047
# 1                                                0.451472
# 2                                                0.379356
# 3                                                0.191231
# 4                                                0.159250
# ...                                                   ...
# 226341                                           0.108499
# 226342                                           0.102590
# 226343                                           0.036352
# 226344                                           0.593201
# 226345                                           0.167751
#
#         ENCSR000EMT.logfc.mean  ENCSR000EMT.jsd_sign.mean  \
# 0                    -0.012129                  -0.010357
# 1                     0.013312                   0.008129
# 2                    -0.018964                  -0.015143
# 3                     0.031934                   0.020760
# 4                    -0.020819                  -0.011900
# ...                        ...                        ...
# 226341               -0.025875                  -0.012848
# 226342               -0.067028                  -0.015264
# 226343               -0.084489                  -0.024247
# 226344               -0.009835                  -0.006762
# 226345               -0.003386                  -0.024856
#
#         ENCSR000EMT.abs_logfc_x_jsd_x_max_percentile.mean  \
# 0                                                0.000075
# 1                                                0.000003
# 2                                                0.000026
# 3                                                0.000623
# 4                                                0.000122
# ...                                                   ...
# 226341                                           0.000313
# 226342                                           0.001260
# 226343                                           0.001716
# 226344                                           0.000003
# 226345                                           0.000652
#
#         ENCSR000EMT.abs_logfc_x_jsd_x_max_percentile.mean.pval  DNASE_SAD  \
# 0                                                0.271773        0.000178
# 1                                                0.697475       -0.000080
# 2                                                0.527638        0.000008
# 3                                                0.105496        0.000026
# 4                                                0.266678       -0.000028
# ...                                                   ...             ...
# 226341                                           0.120968        0.000096
# 226342                                           0.054735       -0.000848
# 226343                                           0.030853       -0.000557
# 226344                                           0.707481        0.000029
# 226345                                           0.074800       -0.000366
#
#         DNASE_SAR  IsUsed  allele1_counts  allele2_counts
# 0        0.000233    True        0.410853        0.411058
# 1       -0.000097    True        0.386183        0.387652
# 2        0.000011    True        0.412326        0.412039
# 3        0.000036    True        0.396623        0.397426
# 4       -0.000037    True        0.407663        0.407715
# ...           ...     ...             ...             ...
# 226341   0.000099    True        0.425780        0.425276
# 226342  -0.001081    True        0.407067        0.406993
# 226343  -0.000713    True        0.422479        0.422674
# 226344   0.000038    True        0.379871        0.378011
# 226345  -0.000515    True        0.475591        0.475039
#
# [226346 rows x 29 columns]

# %%
threshold = np.arange(3,23,2)[0]
threshold = 3
filtered_var_eucaqtls = counts_data[(counts_data["Inside_Peak"]==True) &
                                          (counts_data["IsUsed"]==True)].copy(deep=True)
    
filtered_var_eucaqtls_df_sig = filtered_var_eucaqtls[filtered_var_eucaqtls["Log10_BF"]>threshold].copy(deep=True)
filtered_var_eucaqtls_df_ctrl = filtered_var_eucaqtls[filtered_var_eucaqtls["Log10_BF"]<-1].copy(deep=True)

# %%
data1 = np.abs(filtered_var_eucaqtls_df_ctrl["allele1_counts"] - filtered_var_eucaqtls_df_ctrl["allele2_counts"])

counts1, bins1 = np.histogram(data1, bins=100)
fractions1 = counts1 / counts1.sum()
plt.hist(bins1[:-1], bins1, weights=fractions1, alpha=0.7, label="control")

data2 = np.abs(filtered_var_eucaqtls_df_sig["allele1_counts"] - filtered_var_eucaqtls_df_sig["allele2_counts"])
counts2, bins2 = np.histogram(data2, bins=100)
fractions2 = counts2 / counts2.sum()

plt.hist(bins2[:-1], bins2, weights=fractions2, alpha=0.7, label="significant")
plt.xlabel("Log likelihood ratio")
plt.ylabel("Proportion of Variants")
plt.title("DNABert2 Eu CaQTLs")
# plt.xlim([-0.0001,0.01])
plt.legend()
plt.show()

# %%
fractions1.sum(), fractions2.sum()
# Out:
# (1.0, 1.0)

# %%
data_sorted1 = np.sort(data1)  
cdf1 = np.arange(1, len(data1) + 1) / len(data1)  
plt.plot(data_sorted1, cdf1, marker='.', linestyle='none', alpha=0.5)
plt.xlabel('Data points')
plt.ylabel('CDF')
plt.title('Cumulative Distribution Function (CDF)')

data_sorted2 = np.sort(data2)  
cdf2 = np.arange(1, len(data2) + 1) / len(data2)  
plt.plot(data_sorted2, cdf2, marker='.', linestyle='none', alpha=0.5)
plt.xlabel('Data points')
plt.ylabel('CDF')
plt.title('Cumulative Distribution Function (CDF)')
plt.show()

# %%
data = [data1, data2]

# Create the boxplot
plt.boxplot(data)

# Customizing the plot
plt.xticks([1, 2], ['Control', 'Significant'])  # Set custom labels for the x-axis
plt.ylabel('Value')  # Label for the y-axis
plt.title('Control vs. Significant for DNABert2 Eu CaQTLs')  # Title of the plot
# Out:
# Text(0.5, 1.0, 'Control vs. Significant for DNABert2 Eu CaQTLs')
